# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import confusion_matrix

from matplotlib.colors import ListedColormap
from matplotlib.colors import ListedColormap

# %%
#features
train_df = pd.read_csv('data/train_features.csv')
test_df = pd.read_csv('data/test_data.csv')

train_df.columns = ['ID', 'mon_since_last', 'num_donations', 'tot_vol', 'mon_since_first', 'donated']
test_df.columns = ['ID', 'mon_since_last', 'num_donations', 'tot_vol', 'mon_since_first']

# %%
ids = test_df['ID']
train_df.drop('ID', axis=1, inplace=True)
test_df.drop('ID', axis=1, inplace=True)

train_df.drop('tot_vol', axis=1, inplace=True)
test_df.drop('tot_vol', axis=1, inplace=True)

# %%
X = train_df.drop('donated', axis=1)
y = train_df.donated

# %%
# Splitting the dataset into the Training set and Test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# Feature Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Applying LDA
lda = LDA(n_components = 2)
lda.fit(X,y)
pred = lda.predict_proba(test_df)

# %%
pred
# Out:
# array([[0.58383489, 0.41616511],
#        [0.867593  , 0.132407  ],
#        [0.74450971, 0.25549029],
#        [0.67756107, 0.32243893],
#        [0.52972947, 0.47027053],
#        [0.26365042, 0.73634958],
#        [0.71749697, 0.28250303],
#        [0.8634387 , 0.1365613 ],
#        [0.97345247, 0.02654753],
#        [0.91433571, 0.08566429],
#        [0.82461375, 0.17538625],
#        [0.85090455, 0.14909545],
#        [0.74701969, 0.25298031],
#        [0.74450971, 0.25549029],
#        [0.7444057 , 0.2555943 ],
#        [0.83365656, 0.16634344],
#        [0.76945855, 0.23054145],
#        [0.57014342, 0.42985658],
#        [0.88742337, 0.11257663],
#        [0.74391433, 0.25608567],
#        [0.6445773 , 0.3554227 ],
#        [0.72363215, 0.27636785],
#        [0.67158212, 0.32841788],
#        [0.74450971, 0.25549029],
#        [0.78811741, 0.21188259],
#        [0.70605771, 0.29394229],
#        [0.72023702, 0.27976298],
#        [0.8634387 , 0.1365613 ],
#        [0.73482786, 0.26517214],
#        [0.58383489, 0.41616511],
#        [0.69372085, 0.30627915],
#        [0.94946931, 0.05053069],
#        [0.71394461, 0.28605539],
#        [0.77827597, 0.22172403],
#        [0.83544482, 0.16455518],
#        [0.75472146, 0.24527854],
#        [0.81865132, 0.18134868],
#        [0.8634387 , 0.1365613 ],
#        [0.69667425, 0.30332575],
#        [0.74450971, 0.25549029],
#        [0.69308841, 0.30691159],
#        [0.84123424, 0.15876576],
#        [0.9261198 , 0.0738802 ],
#        [0.69297209, 0.30702791],
#        [0.86846619, 0.13153381],
#        [0.71394461, 0.28605539],
#        [0.69938166, 0.30061834],
#        [0.87678647, 0.12321353],
#        [0.8634387 , 0.1365613 ],
#        [0.82583341, 0.17416659],
#        [0.53922224, 0.46077776],
#        [0.34765873, 0.65234127],
#        [0.83205234, 0.16794766],
#        [0.73835388, 0.26164612],
#        [0.93611381, 0.06388619],
#        [0.80487578, 0.19512422],
#        [0.81665476, 0.18334524],
#        [0.65717566, 0.34282434],
#        [0.75398739, 0.24601261],
#        [0.53762616, 0.46237384],
#        [0.74450971, 0.25549029],
#        [0.87865388, 0.12134612],
#        [0.70458705, 0.29541295],
#        [0.65709009, 0.34290991],
#        [0.87865388, 0.12134612],
#        [0.88770683, 0.11229317],
#        [0.89019922, 0.10980078],
#        [0.75572874, 0.24427126],
#        [0.69286854, 0.30713146],
#        [0.74450971, 0.25549029],
#        [0.81923871, 0.18076129],
#        [0.84783552, 0.15216448],
#        [0.9759484 , 0.0240516 ],
#        [0.74450971, 0.25549029],
#        [0.93534134, 0.06465866],
#        [0.85559228, 0.14440772],
#        [0.8619171 , 0.1380829 ],
#        [0.74653164, 0.25346836],
#        [0.87044785, 0.12955215],
#        [0.65717566, 0.34282434],
#        [0.9759484 , 0.0240516 ],
#        [0.67756107, 0.32243893],
#        [0.72023702, 0.27976298],
#        [0.69308841, 0.30691159],
#        [0.53922224, 0.46077776],
#        [0.9157824 , 0.0842176 ],
#        [0.83365656, 0.16634344],
#        [0.88582718, 0.11417282],
#        [0.75572874, 0.24427126],
#        [0.72141937, 0.27858063],
#        [0.74450971, 0.25549029],
#        [0.86183771, 0.13816229],
#        [0.86846619, 0.13153381],
#        [0.86548437, 0.13451563],
#        [0.7453056 , 0.2546944 ],
#        [0.69369814, 0.30630186],
#        [0.70586244, 0.29413756],
#        [0.72701362, 0.27298638],
#        [0.91266208, 0.08733792],
#        [0.71749697, 0.28250303],
#        [0.71394461, 0.28605539],
#        [0.85867101, 0.14132899],
#        [0.91478646, 0.08521354],
#        [0.78180819, 0.21819181],
#        [0.82748472, 0.17251528],
#        [0.66166292, 0.33833708],
#        [0.75285878, 0.24714122],
#        [0.63582765, 0.36417235],
#        [0.74450971, 0.25549029],
#        [0.86029553, 0.13970447],
#        [0.81006355, 0.18993645],
#        [0.74450971, 0.25549029],
#        [0.94946931, 0.05053069],
#        [0.63566238, 0.36433762],
#        [0.67756107, 0.32243893],
#        [0.93902462, 0.06097538],
#        [0.92698662, 0.07301338],
#        [0.66686696, 0.33313304],
#        [0.41195003, 0.58804997],
#        [0.76319513, 0.23680487],
#        [0.85867101, 0.14132899],
#        [0.59427935, 0.40572065],
#        [0.83616145, 0.16383855],
#        [0.22198525, 0.77801475],
#        [0.64872971, 0.35127029],
#        [0.58214064, 0.41785936],
#        [0.76286837, 0.23713163],
#        [0.81371084, 0.18628916],
#        [0.83616145, 0.16383855],
#        [0.84640612, 0.15359388],
#        [0.7053263 , 0.2946737 ],
#        [0.83365656, 0.16634344],
#        [0.80403753, 0.19596247],
#        [0.74450971, 0.25549029],
#        [0.77827597, 0.22172403],
#        [0.71749697, 0.28250303],
#        [0.83365656, 0.16634344],
#        [0.92781774, 0.07218226],
#        [0.45677684, 0.54322316],
#        [0.76846336, 0.23153664],
#        [0.09817852, 0.90182148],
#        [0.74450971, 0.25549029],
#        [0.72023702, 0.27976298],
#        [0.81665476, 0.18334524],
#        [0.74450971, 0.25549029],
#        [0.92698662, 0.07301338],
#        [0.92350932, 0.07649068],
#        [0.74318185, 0.25681815],
#        [0.95241354, 0.04758646],
#        [0.71394461, 0.28605539],
#        [0.93234693, 0.06765307],
#        [0.54718991, 0.45281009],
#        [0.71583815, 0.28416185],
#        [0.85333987, 0.14666013],
#        [0.85573474, 0.14426526],
#        [0.67843614, 0.32156386],
#        [0.88069949, 0.11930051],
#        [0.71394461, 0.28605539],
#        [0.34765873, 0.65234127],
#        [0.83365656, 0.16634344],
#        [0.70458705, 0.29541295],
#        [0.8634387 , 0.1365613 ],
#        [0.67653883, 0.32346117],
#        [0.61967972, 0.38032028],
#        [0.82859387, 0.17140613],
#        [0.91377513, 0.08622487],
#        [0.72023702, 0.27976298],
#        [0.69372085, 0.30627915],
#        [0.74450971, 0.25549029],
#        [0.74391433, 0.25608567],
#        [0.92698662, 0.07301338],
#        [0.97932888, 0.02067112],
#        [0.74450971, 0.25549029],
#        [0.05804473, 0.94195527],
#        [0.86183771, 0.13816229],
#        [0.9190635 , 0.0809365 ],
#        [0.68368001, 0.31631999],
#        [0.75832072, 0.24167928],
#        [0.90394293, 0.09605707],
#        [0.74450971, 0.25549029],
#        [0.8634387 , 0.1365613 ],
#        [0.81362794, 0.18637206],
#        [0.59427935, 0.40572065],
#        [0.88069949, 0.11930051],
#        [0.56048463, 0.43951537],
#        [0.84640612, 0.15359388],
#        [0.8619171 , 0.1380829 ],
#        [0.83365656, 0.16634344],
#        [0.71394461, 0.28605539],
#        [0.84640612, 0.15359388],
#        [0.28014456, 0.71985544],
#        [0.78983621, 0.21016379],
#        [0.86548437, 0.13451563],
#        [0.879477  , 0.120523  ],
#        [0.85559228, 0.14440772],
#        [0.88069949, 0.11930051],
#        [0.90774045, 0.09225955],
#        [0.88180358, 0.11819642],
#        [0.92396175, 0.07603825],
#        [0.693837  , 0.306163  ]])

# %%
preds=[]
for i in pred:
    preds.append(i[0])
    
preds
# Out:
# [0.583834891123338,
#  0.8675929982125841,
#  0.7445097078918843,
#  0.6775610707317421,
#  0.5297294725190892,
#  0.263650419302516,
#  0.7174969717674908,
#  0.8634387029988078,
#  0.9734524734025966,
#  0.914335709139058,
#  0.8246137503677224,
#  0.8509045541338044,
#  0.7470196947784862,
#  0.7445097078918843,
#  0.7444056964195187,
#  0.8336565633069194,
#  0.769458549699882,
#  0.5701434150142468,
#  0.8874233654553869,
#  0.7439143280964755,
#  0.6445772968720298,
#  0.7236321517118348,
#  0.6715821231001712,
#  0.7445097078918843,
#  0.7881174078640859,
#  0.7060577075695431,
#  0.7202370206398767,
#  0.8634387029988078,
#  0.7348278601780913,
#  0.583834891123338,
#  0.6937208474330478,
#  0.9494693076482901,
#  0.7139446076620561,
#  0.7782759734716481,
#  0.8354448168837525,
#  0.7547214612940781,
#  0.8186513236574883,
#  0.8634387029988078,
#  0.6966742514779034,
#  0.7445097078918843,
#  0.693088406587673,
#  0.84123423699005,
#  0.9261198047727855,
#  0.6929720941404253,
#  0.868466194869967,
#  0.7139446076620561,
#  0.6993816586772215,
#  0.8767864730882851,
#  0.8634387029988078,
#  0.8258334105453924,
#  0.5392222370935955,
#  0.3476587345242599,
#  0.832052344071235,
#  0.7383538766992149,
#  0.9361138147015113,
#  0.8048757799004416,
#  0.8166547573147604,
#  0.6571756639747001,
#  0.7539873871686673,
#  0.5376261615395566,
#  0.7445097078918843,
#  0.878653883386605,
#  0.7045870460308161,
#  0.6570900935080648,
#  0.878653883386605,
#  0.8877068343594033,
#  0.8901992180195798,
#  0.7557287443775196,
#  0.6928685399809582,
#  0.7445097078918843,
#  0.8192387057415904,
#  0.8478355215187012,
#  0.9759483997221547,
#  0.7445097078918843,
#  0.9353413379264668,
#  0.8555922750535478,
#  0.8619170995807434,
#  0.7465316406474863,
#  0.870447846920887,
#  0.6571756639747001,
#  0.9759483997221547,
#  0.6775610707317421,
#  0.7202370206398767,
#  0.693088406587673,
#  0.5392222370935955,
#  0.915782397975858,
#  0.8336565633069194,
#  0.8858271765637139,
#  0.7557287443775196,
#  0.7214193746854962,
#  0.7445097078918843,
#  0.8618377117390161,
#  0.868466194869967,
#  0.8654843661486104,
#  0.7453056031603691,
#  0.6936981385134879,
#  0.7058624372631171,
#  0.7270136193535296,
#  0.9126620831044425,
#  0.7174969717674908,
#  0.7139446076620561,
#  0.8586710111651458,
#  0.9147864630876938,
#  0.7818081903214442,
#  0.8274847160461434,
#  0.6616629207241708,
#  0.7528587793815479,
#  0.635827646972059,
#  0.7445097078918843,
#  0.8602955301093796,
#  0.810063551688318,
#  0.7445097078918843,
#  0.9494693076482901,
#  0.6356623771152912,
#  0.6775610707317421,
#  0.9390246240701208,
#  0.9269866187216987,
#  0.6668669557171941,
#  0.4119500281408347,
#  0.7631951251062071,
#  0.8586710111651458,
#  0.5942793522619758,
#  0.8361614477761895,
#  0.2219852545930615,
#  0.6487297127729531,
#  0.582140644982265,
#  0.7628683653841479,
#  0.8137108363140693,
#  0.8361614477761895,
#  0.84640611943344,
#  0.7053263029162135,
#  0.8336565633069194,
#  0.8040375340170594,
#  0.7445097078918843,
#  0.7782759734716481,
#  0.7174969717674908,
#  0.8336565633069194,
#  0.9278177359994823,
#  0.4567768376801077,
#  0.768463357222622,
#  0.09817852399467175,
#  0.7445097078918843,
#  0.7202370206398767,
#  0.8166547573147604,
#  0.7445097078918843,
#  0.9269866187216987,
#  0.9235093202092781,
#  0.7431818475136893,
#  0.9524135445444467,
#  0.7139446076620561,
#  0.9323469263983019,
#  0.5471899123855618,
#  0.71583815201032,
#  0.8533398728560797,
#  0.8557347415343124,
#  0.6784361425184489,
#  0.880699494243287,
#  0.7139446076620561,
#  0.3476587345242599,
#  0.8336565633069194,
#  0.7045870460308161,
#  0.8634387029988078,
#  0.6765388349127477,
#  0.6196797195323724,
#  0.8285938660901367,
#  0.9137751267061188,
#  0.7202370206398767,
#  0.6937208474330478,
#  0.7445097078918843,
#  0.7439143280964755,
#  0.9269866187216987,
#  0.979328875728854,
#  0.7445097078918843,
#  0.058044729615226776,
#  0.8618377117390161,
#  0.9190634960676177,
#  0.6836800083120638,
#  0.7583207155968714,
#  0.9039429270200736,
#  0.7445097078918843,
#  0.8634387029988078,
#  0.813627944698743,
#  0.5942793522619758,
#  0.880699494243287,
#  0.5604846321359054,
#  0.84640611943344,
#  0.8619170995807434,
#  0.8336565633069194,
#  0.7139446076620561,
#  0.84640611943344,
#  0.2801445638169848,
#  0.7898362064639435,
#  0.8654843661486104,
#  0.8794770048066101,
#  0.8555922750535478,
#  0.880699494243287,
#  0.9077404549095425,
#  0.8818035834376744,
#  0.9239617538754575,
#  0.6938370015485427]

# %%
submission = pd.DataFrame({'': ids, 'Made Donation in March 2007':preds})
submission.to_csv('submission_LDA.csv', index=False)
